# %%
import pandas as pd
import csv as csv

# %%
pd.set_option('display.max_rows', 5752)
df = pd.read_csv("ocorrencia_2010_2020_alterado.csv", sep=';', encoding="cp1252", parse_dates=["ocorrencia_dia"])
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [markdown]
# ## Manipulação dos dados

# %% [markdown]
# ##### a)Localizando um registro ou vários

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[[5]]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5              39807               39807                INCIDENTE
#
#   ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 5          SALVADOR            BA                 ****     2010-06-01
#
#   ocorrencia_hora  total_recomendacoes
# 5        17:53:00                    0

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-04-01
#
#   ocorrencia_hora  total_recomendacoes
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-10-01
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0                         RIO DE JANEIRO
# 1                                  BELÉM
# 2                         RIO DE JANEIRO
# 3                     LUCAS DO RIO VERDE
# 4                                PELOTAS
# 5                               SALVADOR
# 6                                  COARI
# 7                               CANUTAMA
# 8                               CASCAVEL
# 9                          PARÁ DE MINAS
# 10                      SÃO PEDRO DO SUL
# 11                             SÃO PAULO
# 12                              BRASÍLIA
# 13                    PRIMAVERA DO LESTE
# 14                                GURUPÁ
# 15                              CANUTAMA
# 16                             SÃO PAULO
# 17                              SALVADOR
# 18                                SANTOS
# 19                        RIO DE JANEIRO
# 20                       CRUZEIRO DO SUL
# 21                                 FAROL
# 22                           PASSO FUNDO
# ...

# %%
df.ocorrencia_cidade
# Out:
# 0                         RIO DE JANEIRO
# 1                                  BELÉM
# 2                         RIO DE JANEIRO
# 3                     LUCAS DO RIO VERDE
# 4                                PELOTAS
# 5                               SALVADOR
# 6                                  COARI
# 7                               CANUTAMA
# 8                               CASCAVEL
# 9                          PARÁ DE MINAS
# 10                      SÃO PEDRO DO SUL
# 11                             SÃO PAULO
# 12                              BRASÍLIA
# 13                    PRIMAVERA DO LESTE
# 14                                GURUPÁ
# 15                              CANUTAMA
# 16                             SÃO PAULO
# 17                              SALVADOR
# 18                                SANTOS
# 19                        RIO DE JANEIRO
# 20                       CRUZEIRO DO SUL
# 21                                 FAROL
# 22                           PASSO FUNDO
# ...

# %% [markdown]
# ##### b)Alterando um índice ou label do df

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %% [markdown]
# ##### c)Alterando uma coluna qualquer para índice do df

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-05-01 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %% [markdown]
# ##### c)Removendo o index do df, retornando ao original

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-03-01        12:00:00
# 1            PA                 SBBE     2010-03-01        11:05:00
# 2            RJ                 SBRJ     2010-03-01        03:00:00
# 3            MT                 ****     2010-04-01        17:30:00
# 4            RS                 SBPK     2010-05-01        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ## Alteração/Limpeza dos dados

# %% [markdown]
# ##### a)Fazendo um filtro para alterar dados específicos de uma coluna

# %% [raw]
# df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']]= 'GRAVE'

# %% [raw]
# df.loc[df.ocorrencia_uf == 'SP']

# %% [markdown]
# ##### b)Fazendo limpeza das colunas 'ocorrencia_uf'	,  'ocorrencia_aerodromo' e	'ocorrencia_hora'
#
# valores Null, valores *** etc

# %% [markdown]
# ######  c) Trocando somente (****) por (NA ) em uma Coluna específica - > 'ocorrencia_aerodromo'

# %%
df.loc[df.ocorrencia_aerodromo =='*****', ['ocorrencia_aerodromo']]= pd.NA

# %%
df.ocorrencia_aerodromo
# Out:
# 0       ****
# 1       SBBE
# 2       SBRJ
# 3       ****
# 4       SBPK
# 5       ****
# 6       SBUY
# 7       ****
# 8       SBCA
# 9       ****
# 10      ****
# 11      SBMT
# 12      SBBR
# 13      ****
# 14      SNGU
# 15      ****
# 16      ****
# 17      ****
# 18      ****
# 19      SBGL
# 20      SBCZ
# 21      ****
# 22      SBPF
# 23      ****
# 24      ****
# 25      ****
# 26      ****
# 27      ****
# 28      ****
# 29      SBBI
# 30      SBGL
# 31      ****
# 32      ****
# 33      SBGR
# 34      ****
# 35      SBPJ
# 36      SBJC
# 37      ****
# 38      SBFL
# 39      SBGL
# 40      ****
# 41      ****
# 42      SNCL
# 43      SBGO
# 44      ****
# 45      ****
# 46      ****
# 47      ****
# 48      ****
# 49      ****
# 50      SBCZ
# 51      SNTY
# 52      SBSR
# 53      ****
# 54      SBVT
# 55      ****
# 56      SBPC
# 57      SBSV
# 58      ****
# 59      ****
# 60      ****
# 61      ****
# 62      SBCT
# 63      SBMT
# 64      ****
# 65      ****
# ...

# %%
df.loc[df.ocorrencia_aerodromo =='****', ['ocorrencia_aerodromo']]= pd.NA

# %%
df.ocorrencia_aerodromo
# Out:
# 0       <NA>
# 1       SBBE
# 2       SBRJ
# 3       <NA>
# 4       SBPK
# 5       <NA>
# 6       SBUY
# 7       <NA>
# 8       SBCA
# 9       <NA>
# 10      <NA>
# 11      SBMT
# 12      SBBR
# 13      <NA>
# 14      SNGU
# 15      <NA>
# 16      <NA>
# 17      <NA>
# 18      <NA>
# 19      SBGL
# 20      SBCZ
# 21      <NA>
# 22      SBPF
# 23      <NA>
# 24      <NA>
# 25      <NA>
# 26      <NA>
# 27      <NA>
# 28      <NA>
# 29      SBBI
# 30      SBGL
# 31      <NA>
# 32      <NA>
# 33      SBGR
# 34      <NA>
# 35      SBPJ
# 36      SBJC
# 37      <NA>
# 38      SBFL
# 39      SBGL
# 40      <NA>
# 41      <NA>
# 42      SNCL
# 43      SBGO
# 44      <NA>
# 45      <NA>
# 46      <NA>
# 47      <NA>
# 48      <NA>
# 49      <NA>
# 50      SBCZ
# 51      SNTY
# 52      SBSR
# 53      <NA>
# 54      SBVT
# 55      <NA>
# 56      SBPC
# 57      SBSV
# 58      <NA>
# 59      <NA>
# 60      <NA>
# 61      <NA>
# 62      SBCT
# 63      SBMT
# 64      <NA>
# 65      <NA>
# ...

# %% [markdown]
# ###### d) Trocando todas AS OCORRÊNCIAS ERRADAS por NA

# %%
df.replace(['***','****','*****','###!', '####', 'NULL'], pd.NA, inplace=True)

# %%
df.ocorrencia_aerodromo
# Out:
# 0       <NA>
# 1       SBBE
# 2       SBRJ
# 3       <NA>
# 4       SBPK
# 5       <NA>
# 6       SBUY
# 7       <NA>
# 8       SBCA
# 9       <NA>
# 10      <NA>
# 11      SBMT
# 12      SBBR
# 13      <NA>
# 14      SNGU
# 15      <NA>
# 16      <NA>
# 17      <NA>
# 18      <NA>
# 19      SBGL
# 20      SBCZ
# 21      <NA>
# 22      SBPF
# 23      <NA>
# 24      <NA>
# 25      <NA>
# 26      <NA>
# 27      <NA>
# 28      <NA>
# 29      SBBI
# 30      SBGL
# 31      <NA>
# 32      <NA>
# 33      SBGR
# 34      <NA>
# 35      SBPJ
# 36      SBJC
# 37      <NA>
# 38      SBFL
# 39      SBGL
# 40      <NA>
# 41      <NA>
# 42      SNCL
# 43      SBGO
# 44      <NA>
# 45      <NA>
# 46      <NA>
# 47      <NA>
# 48      <NA>
# 49      <NA>
# 50      SBCZ
# 51      SNTY
# 52      SBSR
# 53      <NA>
# 54      SBVT
# 55      <NA>
# 56      SBPC
# 57      SBSV
# 58      <NA>
# 59      <NA>
# 60      <NA>
# 61      <NA>
# 62      SBCT
# 63      SBMT
# 64      <NA>
# 65      <NA>
# ...

# %% [markdown]
# ###### e) Contando todas AS OCORRÊNCIAS de NA

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2331
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# ###### e) Contando todas AS OCORRÊNCIAS de NULL

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2331
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [markdown]
# ###### f) Trocando todas AS OCORRÊNCIAS de NA por  (0) zero

# %%
df.fillna(0, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia           0
# codigo_ocorrencia2          0
# ocorrencia_classificacao    0
# ocorrencia_cidade           0
# ocorrencia_uf               0
# ocorrencia_aerodromo        0
# ocorrencia_dia              0
# ocorrencia_hora             0
# total_recomendacoes         0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                    0     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                    0     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [markdown]
# ###### CRIANDO E EXCLUINDO COLUNAS CRIADAS

# %%
df['total_recomendacoes_bkp']= df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                    0     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                    0     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
#
#   ocorrencia_hora  total_recomendacoes  total_recomendacoes_bkp
# 0        12:00:00                    0                        0
# ...

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                    0     2010-03-01
# 1               BELÉM            PA                 SBBE     2010-03-01
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-03-01
# 3  LUCAS DO RIO VERDE            MT                    0     2010-04-01
# 4             PELOTAS            RS                 SBPK     2010-05-01
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# ...

# %% [markdown]
# ######  EXCLUINDO TODAS AS LINHAS QUE POSSUEM NA

# %% [raw]
# df.dropna()

# %% [raw]
# df.dropna(subset=['ocorencia_uf'])

# %% [markdown]
# ######  EXCLUINDO VALORES DUPLICADOS

# %% [raw]
# df.drop_duplicates(inplace=True)

# %% [markdown]
# ######  EXCLUINDO VALORES OUTLIERS
